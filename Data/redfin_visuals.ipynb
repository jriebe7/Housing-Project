# %%
 # Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Read CSVs
median_prices = pd.read_csv("../Resources/sales_price_clean_csv")
median_prices
# Out:
#          Month  National  Austin, TX  Idaho Falls, ID  Pine Bluff, AR  \
# 0   2019-01-01       273         342              195              50
# 1   2019-02-01       276         347              177              40
# 2   2019-03-01       284         365              185              60
# 3   2019-04-01       290         380              186              88
# 4   2019-05-01       299         392              195              84
# ..         ...       ...         ...              ...             ...
# 59  2023-12-01       402         520              330              76
# 60  2024-01-01       402         500              299             100
# 61  2024-02-01       412         524              345              60
# 62  2024-03-01       420         550              330             126
# 63  2024-04-01       434         575              353              98
#
#     Shreveport,LA
# 0             155
# 1             120
# 2             153
# 3             150
# 4             150
# ...

# %%
median_prices.plot(x="Month", y=["National", "Austin, TX","Idaho Falls, ID","Pine Bluff, AR","Shreveport,LA"], xlabel="Year",
         ylabel="Median House price ($1,000s)", title="Median Home Sale Price")

#Set tickmarks to years
x1=[0,11,23,35,47,59]
labels = [2019, 2020, 2021, 2022, 2023, 2024]
plt.xticks(x1, labels,rotation=45)
#Save figure
plt.savefig("med_home_price.png",bbox_inches = "tight")
plt.show()

# %%
#Read CSVs
sales_qtys = pd.read_csv("../Resources/sales_qty_clean_csv")
sales_qtys
# Out:
#          Month  National  Austin, TX  Idaho Falls, ID  Pine Bluff, AR  \
# 0   2019-01-01    332655         728               55               9
# 1   2019-02-01    370924         925               58              22
# 2   2019-03-01    485757        1108               66              18
# 3   2019-04-01    546067        1267               84              18
# 4   2019-05-01    641458        1490              120              26
# ..         ...       ...         ...              ...             ...
# 59  2023-12-01    358212         628               60              17
# 60  2024-01-01    288939         515               44              20
# 61  2024-02-01    341003         707               70              25
# 62  2024-03-01    409356         852               73              22
# 63  2024-04-01    445800         909               72              23
#
#     Shreveport,LA
# 0              25
# 1              25
# 2              22
# 3              29
# 4              20
# ...

# %%
import scipy.stats as st
from scipy.stats import linregress

sales_qtys.plot(x="Month", y="National", xlabel="Year",
         ylabel="Number of Homes Sold", title="Homes Sold")

#Set tickmarks to years
x1=[0,11,23,35,47,59]
labels = [2019, 2020, 2021, 2022, 2023, 2024]
plt.xticks(x1, labels,rotation=45)

# Calculate the correlation coefficient and a linear regression model 
# correlation = round(st.pearsonr(sales_qtys["Month"],sales_qtys["National"])[0],2)

x_values = sales_qtys["Month"]
y_values = sales_qtys["National"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")

#Save figure
plt.savefig("national_home_sales_qty.png",bbox_inches = "tight")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 17
#      15 x_values = sales_qtys["Month"]
#      16 y_values = sales_qtys["National"]
# ---> 17 (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
#      18 regress_values = x_values * slope + intercept
#      19 line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#
# File c:\Users\domin\anaconda3\Lib\site-packages\scipy\stats\_stats_mstats_common.py:161, in linregress(x, y, alternative)
#     157     raise ValueError("Cannot calculate a linear regression "
#     158                      "if all x values are identical")
#     160 n = len(x)
# --> 161 xmean = np.mean(x, None)
#     162 ymean = np.mean(y, None)
#     164 # Average sums of square differences from the mean
#     165 #   ssxm = mean( (x-mean(x))^2 )
# ...

# %%
sales_qtys.plot(x="Month", y=["Austin, TX","Idaho Falls, ID","Pine Bluff, AR","Shreveport,LA"], xlabel="Year",
         ylabel="Number of Homes Sold", title="Homes Sold")

#Set tickmarks to years
x1=[0,11,23,35,47,59]
labels = [2019, 2020, 2021, 2022, 2023, 2024]
plt.xticks(x1, labels,rotation=45)
#Save figure
plt.savefig("city_home_sales_qty.png",bbox_inches = "tight")
plt.show()

# %%
sales_qtys.plot(x="Month", y=["National","Austin, TX","Idaho Falls, ID","Pine Bluff, AR","Shreveport,LA"], xlabel="Year",
         ylabel="Number of Homes Sold", title="Homes Sold")

#Set tickmarks to years
x1=[0,11,23,35,47,59]
labels = [2019, 2020, 2021, 2022, 2023, 2024]
plt.xticks(x1, labels,rotation=45)
#Save figure
plt.savefig("total_home_sales_qty.png",bbox_inches = "tight")
plt.show()
